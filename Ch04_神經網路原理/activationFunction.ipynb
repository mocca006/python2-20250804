# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.arange(-7, 7, 0.1)
print(len(z))
# Out:
# 140

# %%
def sigmoid(z):
    return 1.0 / (1.0 + np.exp(-z))

# %%
phi_z = sigmoid(z)

plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
#plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$') #label for the sigmoid function

# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca() # get current axis
ax.yaxis.grid(True) # horizontal gridlines

plt.tight_layout()
#plt.savefig('images/03_02.png', dpi=300)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\monic\AppData\Local\Temp\ipykernel_16136\2732715582.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$\phi (z)$')

# %%
def softmax(x):
    return np.exp(x)/sum(np.exp(x))

# %%
phi_z = softmax(z)

plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
#plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')

# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca()
ax.yaxis.grid(True)

plt.tight_layout()
#plt.savefig('images/03_02.png', dpi=300)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\monic\AppData\Local\Temp\ipykernel_16136\2937672030.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$\phi (z)$')

# %%
def tanh(x):
    s1 = np.exp(x) - np.exp(-x)
    s2 = np.exp(x) + np.exp(-x)
    s = s1 / s2
    return s

# %%
phi_z = tanh(z)

plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
#plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')

# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca()
ax.yaxis.grid(True)

plt.tight_layout()
#plt.savefig('images/03_02.png', dpi=300)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\monic\AppData\Local\Temp\ipykernel_16136\897064693.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$\phi (z)$')

# %%
def relu(x):
    s = np.where(x < 0, 0, x)
    return s

# %%
phi_z = relu(z)

plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
#plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')

# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca()
ax.yaxis.grid(True)

plt.tight_layout()
#plt.savefig('images/03_02.png', dpi=300)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# <>:7: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\monic\AppData\Local\Temp\ipykernel_16136\3241064668.py:7: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$\phi (z)$')

# %%
def leaky_relu(x, a):
    if x < 0: return a*x
    else: return x

def plot(px, py):
    plt.plot(px, py)
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.spines['bottom'].set_position(('data',0))
    ax.yaxis.set_ticks_position('left')
    ax.spines['left'].set_position(('data',0))
    plt.show()

a = 0.07
x = []
dx = -20
while dx <= 20:
    x.append(dx)
    dx += 0.1

# px and py
px = [xv for xv in x]
py = [leaky_relu(xv, a) for xv in x]

# Plot
plot(px, py)
