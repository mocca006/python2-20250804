# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('tree.jpg')
plt.imshow(img)
plt.show()

# %%
img2 = cv2.resize(img, (80,40))
plt.imshow(img2)
plt.show()

# %%
px = img[100,100]
print(px)
# Out:
# [ 7  3 78]

# %%
blue = img[100,100,0]# BGR[0],即只讀藍色
print(blue)
# Out:
# 7
